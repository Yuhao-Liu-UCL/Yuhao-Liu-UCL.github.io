# %%
#read all libraries that reqired to run this project 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
#read attribute data
data = pd.read_excel('/Users/richshen/Desktop/GMP_GW/GMP_data.csv')

data.head()
# Out:
# /Users/richshen/opt/anaconda3/envs/sds2020/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Your version of xlrd is 1.2.0. In xlrd >= 2.0, only the xls format is supported. As a result, the openpyxl engine will be used if it is installed and the engine argument is not specified. Install openpyxl instead.
#                                Ward name Old code   New code  \
# 0                         City of London     00AA  E09000001
# 1           Barking and Dagenham - Abbey   00ABFX  E05000026
# 2          Barking and Dagenham - Alibon   00ABFY  E05000027
# 3       Barking and Dagenham - Becontree   00ABFZ  E05000028
# 4  Barking and Dagenham - Chadwell Heath   00ABGA  E05000029
#
#    Average GCSE capped point scores - 2014  % with no qualifications - 2011  \
# 0                               354.500000                              6.7
# 1                               317.657759                             16.4
# ...

# %%
url = 'https://data.london.gov.uk/download/statistical-gis-boundary-files-london/9ba8c833-6370-4b11-abdc-314aa020d5e0/statistical-gis-boundaries-london.zip'

! wget $url
# Out:
# --2021-05-05 17:07:09--  https://data.london.gov.uk/download/statistical-gis-boundary-files-london/9ba8c833-6370-4b11-abdc-314aa020d5e0/statistical-gis-boundaries-london.zip
# 正在解析主机 data.london.gov.uk (data.london.gov.uk)... 143.204.186.61, 143.204.186.41, 143.204.186.30, ...
# 正在连接 data.london.gov.uk (data.london.gov.uk)|143.204.186.61|:443... 已连接。
# 已发出 HTTP 请求，正在等待回应... 302 Moved Temporarily
# 位置：https://airdrive-secure.s3-eu-west-1.amazonaws.com/london/dataset/statistical-gis-boundary-files-london/2016-10-03T13%3A52%3A28/statistical-gis-boundaries-london.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAJJDIMAIVZJDICKHA%2F20210505%2Feu-west-1%2Fs3%2Faws4_request&X-Amz-Date=20210505T160710Z&X-Amz-Expires=300&X-Amz-Signature=721103ad05f951aea5691377a4b71f57f7fcda2883f132ddd50d150b754a4da1&X-Amz-SignedHeaders=host [跟随至新的 URL]
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 7 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Ward name                                          625 non-null    object
#  1   Old code                                           625 non-null    object
#  2   New code                                           625 non-null    object
#  3   Average GCSE capped point scores - 2014            625 non-null    float64
#  4   % with no qualifications - 2011                    625 non-null    float64
#  5   % with Level 4 qualifications and above - 2011     625 non-null    float64
#  6   A-Level Average Point Score Per Student - 2013/14  625 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 34.3+ KB

# %%
map_df = gpd.read_file(f"zip://statistical-gis-boundaries-london.zip!statistical-gis-boundaries-london/ESRI/London_Ward_CityMerged.shp")
map_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAME        625 non-null    object
#  1   GSS_CODE    625 non-null    object
#  2   HECTARES    625 non-null    float64
#  3   NONLD_AREA  625 non-null    float64
#  4   LB_GSS_CD   625 non-null    object
#  5   BOROUGH     625 non-null    object
#  6   POLY_ID     625 non-null    int64
#  7   geometry    625 non-null    geometry
# dtypes: float64(2), geometry(1), int64(1), object(4)
# memory usage: 39.2+ KB

# %%
merged = map_df.set_index('GSS_CODE').join(data.set_index('New code'))

# %%
merged
# Out:
#                              NAME  HECTARES  NONLD_AREA  LB_GSS_CD  \
# GSS_CODE
# E05000405       Chessington South   755.173       0.000  E09000021
# E05000414  Tolworth and Hook Rise   259.464       0.000  E09000021
# E05000401              Berrylands   145.390       0.000  E09000021
# E05000400               Alexandra   268.506       0.000  E09000021
# E05000402                Beverley   187.821       0.000  E09000021
# ...                           ...       ...         ...        ...
# E05000042               Whalebone   155.399       0.000  E09000002
# E05000030               Eastbrook   345.060       0.000  E09000002
# E05000029          Chadwell Heath   338.422       0.000  E09000002
# E05000037                Parsloes   124.384       0.000  E09000002
# E09000001          City of London   314.943      24.546  E09000001
#
#                         BOROUGH  POLY_ID  \
# GSS_CODE
# E05000405  Kingston upon Thames    50840
# E05000414  Kingston upon Thames   117160
# ...

# %%
merged.to_csv(r'/Users/richshen/Desktop/GMP_new.csv')

# %%
merged.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 625 entries, E05000405 to E09000001
# Data columns (total 13 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   NAME                                               625 non-null    object
#  1   HECTARES                                           625 non-null    float64
#  2   NONLD_AREA                                         625 non-null    float64
#  3   LB_GSS_CD                                          625 non-null    object
#  4   BOROUGH                                            625 non-null    object
#  5   POLY_ID                                            625 non-null    int64
#  6   geometry                                           625 non-null    geometry
#  7   Ward name                                          625 non-null    object
# ...

# %%
merged = merged.to_crs(epsg=4326)

# %%
merged.to_file(r'/Users/richshen/Desktop/GMP_json.geojson', driver="GeoJSON")
